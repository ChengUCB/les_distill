# %% [markdown]
# # Water BEC benchmark
#
# This notebook reproduces the water BEC parity and kPCA benchmark figures from the packaged `data/` directory. It is a clean relative-path version of the original BEC_DFT notebook workflow.

# %%
import sys
from pathlib import Path

candidate_dirs = [
    Path.cwd(),
    Path.cwd() / "water_BEC",
    Path.cwd() / "System1_water" / "water_BEC",
]
for candidate_dir in candidate_dirs:
    if (candidate_dir / "water_BEC_benchmark.py").exists():
        sys.path.insert(0, str(candidate_dir.resolve()))
        break

from water_BEC_benchmark import (
    DEFAULT_DATA_DIR,
    DEFAULT_OUTPUT_DIR,
    all_required_files,
    plot_bec_parity,
    plot_kpca_similarity,
    validate_inputs,
)

DATA_DIR = DEFAULT_DATA_DIR
OUTPUT_DIR = DEFAULT_OUTPUT_DIR
DATA_DIR, OUTPUT_DIR

# %%
validate_inputs(DATA_DIR)
print(f"Found {len(all_required_files())} packaged benchmark files in {DATA_DIR}")

# %%
parity_path = plot_bec_parity(data_dir=DATA_DIR, output_dir=OUTPUT_DIR)
parity_path

# %%
kpca_path = plot_kpca_similarity(data_dir=DATA_DIR, output_dir=OUTPUT_DIR, n_frames=100)
kpca_path
